# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Automobile_Dataset.csv")
data_copy = df.copy(deep='False')
data_copy.head()
# Out:
#    symboling normalized-losses         make  ... city-mpg highway-mpg  price
# 0          3                 ?  alfa-romero  ...       21          27  13495
# 1          3                 ?  alfa-romero  ...       21          27  16500
# 2          1                 ?  alfa-romero  ...       19          26  16500
# 3          2               164         audi  ...       24          30  13950
# 4          2               164         audi  ...       18          22  17450
#
# [5 rows x 26 columns]

# %%
data_copy['normalized-losses'] = pd.to_numeric(data_copy['normalized-losses'], errors="coerce")
data_copy['normalized-losses'] = data_copy['normalized-losses'].fillna((data_copy['normalized-losses'].mean()), inplace=False)
data_copy.head()
# Out:
#    symboling  normalized-losses         make  ... city-mpg highway-mpg  price
# 0          3              122.0  alfa-romero  ...       21          27  13495
# 1          3              122.0  alfa-romero  ...       21          27  16500
# 2          1              122.0  alfa-romero  ...       19          26  16500
# 3          2              164.0         audi  ...       24          30  13950
# 4          2              164.0         audi  ...       18          22  17450
#
# [5 rows x 26 columns]

# %%
data_copy['bore'] = pd.to_numeric(data_copy['bore'], errors="coerce")
data_copy['bore'] = data_copy['bore'].fillna((data_copy['bore'].mean()), inplace=False)
data_copy.head()
# Out:
#    symboling  normalized-losses         make  ... city-mpg highway-mpg  price
# 0          3              122.0  alfa-romero  ...       21          27  13495
# 1          3              122.0  alfa-romero  ...       21          27  16500
# 2          1              122.0  alfa-romero  ...       19          26  16500
# 3          2              164.0         audi  ...       24          30  13950
# 4          2              164.0         audi  ...       18          22  17450
#
# [5 rows x 26 columns]

# %%
data_copy['stroke'] = pd.to_numeric(data_copy['stroke'], errors="coerce")
data_copy['stroke'] = data_copy['stroke'].fillna((data_copy['stroke'].mean()), inplace=False)
data_copy.head()
# Out:
#    symboling  normalized-losses         make  ... city-mpg highway-mpg  price
# 0          3              122.0  alfa-romero  ...       21          27  13495
# 1          3              122.0  alfa-romero  ...       21          27  16500
# 2          1              122.0  alfa-romero  ...       19          26  16500
# 3          2              164.0         audi  ...       24          30  13950
# 4          2              164.0         audi  ...       18          22  17450
#
# [5 rows x 26 columns]

# %%
data_copy['horsepower'] = pd.to_numeric(data_copy['horsepower'], errors="coerce")
data_copy['horsepower'] = data_copy['horsepower'].fillna((data_copy['horsepower'].mean()), inplace=False)
data_copy.head()
# Out:
#    symboling  normalized-losses         make  ... city-mpg highway-mpg  price
# 0          3              122.0  alfa-romero  ...       21          27  13495
# 1          3              122.0  alfa-romero  ...       21          27  16500
# 2          1              122.0  alfa-romero  ...       19          26  16500
# 3          2              164.0         audi  ...       24          30  13950
# 4          2              164.0         audi  ...       18          22  17450
#
# [5 rows x 26 columns]

# %%
data_copy['peak-rpm'] = pd.to_numeric(data_copy['peak-rpm'], errors="coerce")
data_copy['peak-rpm'] = data_copy['peak-rpm'].fillna((data_copy['peak-rpm'].mean()), inplace=False)
data_copy.head()
# Out:
#    symboling  normalized-losses         make  ... city-mpg highway-mpg  price
# 0          3              122.0  alfa-romero  ...       21          27  13495
# 1          3              122.0  alfa-romero  ...       21          27  16500
# 2          1              122.0  alfa-romero  ...       19          26  16500
# 3          2              164.0         audi  ...       24          30  13950
# 4          2              164.0         audi  ...       18          22  17450
#
# [5 rows x 26 columns]

# %%
data_copy['price'] = pd.to_numeric(data_copy['price'], errors="coerce")
data_copy['price'] = data_copy['price'].fillna((data_copy['price'].mean()), inplace=False)
data_copy.head()
# Out:
#    symboling  normalized-losses         make  ... city-mpg highway-mpg    price
# 0          3              122.0  alfa-romero  ...       21          27  13495.0
# 1          3              122.0  alfa-romero  ...       21          27  16500.0
# 2          1              122.0  alfa-romero  ...       19          26  16500.0
# 3          2              164.0         audi  ...       24          30  13950.0
# 4          2              164.0         audi  ...       18          22  17450.0
#
# [5 rows x 26 columns]

# %%
data_copy["fuel-type"] = data_copy["fuel-type"].astype('category')
data_copy.dtypes
# Out:
# symboling               int64
# normalized-losses     float64
# make                   object
# fuel-type            category
# aspiration             object
# num-of-doors           object
# body-style             object
# drive-wheels           object
# engine-location        object
# wheel-base            float64
# length                float64
# width                 float64
# height                float64
# curb-weight             int64
# engine-type            object
# num-of-cylinders       object
# engine-size             int64
# fuel-system            object
# bore                  float64
# stroke                float64
# compression-ratio     float64
# horsepower            float64
# peak-rpm              float64
# city-mpg                int64
# highway-mpg             int64
# price                 float64
# dtype: object

# %%
data_copy["fuel-type-code"] = data_copy["fuel-type"].cat.codes
data_copy.head()
# Out:
#    symboling  normalized-losses  ...    price fuel-type-code
# 0          3              122.0  ...  13495.0              1
# 1          3              122.0  ...  16500.0              1
# 2          1              122.0  ...  16500.0              1
# 3          2              164.0  ...  13950.0              1
# 4          2              164.0  ...  17450.0              1
#
# [5 rows x 27 columns]

# %%
data_copy["aspiration"] = data_copy["aspiration"].astype('category')
data_copy.dtypes
# Out:
# symboling               int64
# normalized-losses     float64
# make                   object
# fuel-type            category
# aspiration           category
# num-of-doors           object
# body-style             object
# drive-wheels           object
# engine-location        object
# wheel-base            float64
# length                float64
# width                 float64
# height                float64
# curb-weight             int64
# engine-type            object
# num-of-cylinders       object
# engine-size             int64
# fuel-system            object
# bore                  float64
# stroke                float64
# compression-ratio     float64
# horsepower            float64
# peak-rpm              float64
# city-mpg                int64
# highway-mpg             int64
# price                 float64
# fuel-type-code           int8
# dtype: object

# %%
data_copy["aspiration-code"] = data_copy["aspiration"].cat.codes
data_copy.head()
# Out:
#    symboling  normalized-losses  ... fuel-type-code aspiration-code
# 0          3              122.0  ...              1               0
# 1          3              122.0  ...              1               0
# 2          1              122.0  ...              1               0
# 3          2              164.0  ...              1               0
# 4          2              164.0  ...              1               0
#
# [5 rows x 28 columns]

# %%
data_copy['num-of-doors'] = data_copy['num-of-doors'].replace('?','four')

# %%
string_to_number = {"num-of-doors":     {"four": 4, "two": 2},
                "num-of-cylinders": {"four": 4, "six": 6, "five": 5, "eight": 8,
                                  "two": 2, "twelve": 12, "three":3 }}

data_copy = data_copy.replace(string_to_number)
data_copy.head()
# Out:
#    symboling  normalized-losses  ... fuel-type-code aspiration-code
# 0          3              122.0  ...              1               0
# 1          3              122.0  ...              1               0
# 2          1              122.0  ...              1               0
# 3          2              164.0  ...              1               0
# 4          2              164.0  ...              1               0
#
# [5 rows x 28 columns]

# %%
data_copy["body-style"] = data_copy["body-style"].astype('category')
data_copy.dtypes
# Out:
# symboling               int64
# normalized-losses     float64
# make                   object
# fuel-type            category
# aspiration           category
# num-of-doors            int64
# body-style           category
# drive-wheels           object
# engine-location        object
# wheel-base            float64
# length                float64
# width                 float64
# height                float64
# curb-weight             int64
# engine-type            object
# num-of-cylinders        int64
# engine-size             int64
# fuel-system            object
# bore                  float64
# stroke                float64
# compression-ratio     float64
# horsepower            float64
# peak-rpm              float64
# city-mpg                int64
# highway-mpg             int64
# price                 float64
# fuel-type-code           int8
# aspiration-code          int8
# dtype: object

# %%
data_copy["body-style-code"] = data_copy["body-style"].cat.codes
data_copy.head()
# Out:
#    symboling  normalized-losses  ... aspiration-code body-style-code
# 0          3              122.0  ...               0               0
# 1          3              122.0  ...               0               0
# 2          1              122.0  ...               0               2
# 3          2              164.0  ...               0               3
# 4          2              164.0  ...               0               3
#
# [5 rows x 29 columns]

# %%
data_copy["engine-location"] = data_copy["engine-location"].astype('category')
data_copy.dtypes
# Out:
# symboling               int64
# normalized-losses     float64
# make                   object
# fuel-type            category
# aspiration           category
# num-of-doors            int64
# body-style           category
# drive-wheels           object
# engine-location      category
# wheel-base            float64
# length                float64
# width                 float64
# height                float64
# curb-weight             int64
# engine-type            object
# num-of-cylinders        int64
# engine-size             int64
# fuel-system            object
# bore                  float64
# stroke                float64
# compression-ratio     float64
# horsepower            float64
# peak-rpm              float64
# city-mpg                int64
# highway-mpg             int64
# price                 float64
# fuel-type-code           int8
# aspiration-code          int8
# body-style-code          int8
# dtype: object

# %%
data_copy["engine-locatione-code"] = data_copy["engine-location"].cat.codes
data_copy.head()
# Out:
#    symboling  normalized-losses  ... body-style-code engine-locatione-code
# 0          3              122.0  ...               0                     0
# 1          3              122.0  ...               0                     0
# 2          1              122.0  ...               2                     0
# 3          2              164.0  ...               3                     0
# 4          2              164.0  ...               3                     0
#
# [5 rows x 30 columns]

# %%
data_copy["engine-type"] = data_copy["engine-type"].astype('category')
data_copy.dtypes
# Out:
# symboling                   int64
# normalized-losses         float64
# make                       object
# fuel-type                category
# aspiration               category
# num-of-doors                int64
# body-style               category
# drive-wheels               object
# engine-location          category
# wheel-base                float64
# length                    float64
# width                     float64
# height                    float64
# curb-weight                 int64
# engine-type              category
# num-of-cylinders            int64
# engine-size                 int64
# fuel-system                object
# bore                      float64
# stroke                    float64
# compression-ratio         float64
# horsepower                float64
# peak-rpm                  float64
# city-mpg                    int64
# highway-mpg                 int64
# price                     float64
# fuel-type-code               int8
# ...

# %%
data_copy["engine-type-code"] = data_copy["engine-type"].cat.codes
data_copy.head()
# Out:
#    symboling  normalized-losses  ... engine-locatione-code engine-type-code
# 0          3              122.0  ...                     0                0
# 1          3              122.0  ...                     0                0
# 2          1              122.0  ...                     0                5
# 3          2              164.0  ...                     0                3
# 4          2              164.0  ...                     0                3
#
# [5 rows x 31 columns]

# %%
data_copy["fuel-system"] = data_copy["fuel-system"].astype('category')
data_copy.dtypes
# Out:
# symboling                   int64
# normalized-losses         float64
# make                       object
# fuel-type                category
# aspiration               category
# num-of-doors                int64
# body-style               category
# drive-wheels               object
# engine-location          category
# wheel-base                float64
# length                    float64
# width                     float64
# height                    float64
# curb-weight                 int64
# engine-type              category
# num-of-cylinders            int64
# engine-size                 int64
# fuel-system              category
# bore                      float64
# stroke                    float64
# compression-ratio         float64
# horsepower                float64
# peak-rpm                  float64
# city-mpg                    int64
# highway-mpg                 int64
# price                     float64
# fuel-type-code               int8
# ...

# %%
data_copy["fuel-system-code"] = data_copy["fuel-system"].cat.codes
data_copy.head()
# Out:
#    symboling  normalized-losses  ... engine-type-code fuel-system-code
# 0          3              122.0  ...                0                5
# 1          3              122.0  ...                0                5
# 2          1              122.0  ...                5                5
# 3          2              164.0  ...                3                5
# 4          2              164.0  ...                3                5
#
# [5 rows x 32 columns]

# %%
data_copy["drive-wheels"] = data_copy["drive-wheels"].astype('category')
data_copy.dtypes
# Out:
# symboling                   int64
# normalized-losses         float64
# make                       object
# fuel-type                category
# aspiration               category
# num-of-doors                int64
# body-style               category
# drive-wheels             category
# engine-location          category
# wheel-base                float64
# length                    float64
# width                     float64
# height                    float64
# curb-weight                 int64
# engine-type              category
# num-of-cylinders            int64
# engine-size                 int64
# fuel-system              category
# bore                      float64
# stroke                    float64
# compression-ratio         float64
# horsepower                float64
# peak-rpm                  float64
# city-mpg                    int64
# highway-mpg                 int64
# price                     float64
# fuel-type-code               int8
# ...

# %%
data_copy["drive-wheels-code"] = data_copy["drive-wheels"].cat.codes
data_copy.head()
# Out:
#    symboling  normalized-losses  ... fuel-system-code drive-wheels-code
# 0          3              122.0  ...                5                 2
# 1          3              122.0  ...                5                 2
# 2          1              122.0  ...                5                 2
# 3          2              164.0  ...                5                 1
# 4          2              164.0  ...                5                 0
#
# [5 rows x 33 columns]

# %%
data_copy["make"] = data_copy["make"].astype('category')
data_copy.dtypes
# Out:
# symboling                   int64
# normalized-losses         float64
# make                     category
# fuel-type                category
# aspiration               category
# num-of-doors                int64
# body-style               category
# drive-wheels             category
# engine-location          category
# wheel-base                float64
# length                    float64
# width                     float64
# height                    float64
# curb-weight                 int64
# engine-type              category
# num-of-cylinders            int64
# engine-size                 int64
# fuel-system              category
# bore                      float64
# stroke                    float64
# compression-ratio         float64
# horsepower                float64
# peak-rpm                  float64
# city-mpg                    int64
# highway-mpg                 int64
# price                     float64
# fuel-type-code               int8
# ...

# %%
data_copy["make-code"] = data_copy["make"].cat.codes
data_copy.head()
# Out:
#    symboling  normalized-losses  ... drive-wheels-code make-code
# 0          3              122.0  ...                 2         0
# 1          3              122.0  ...                 2         0
# 2          1              122.0  ...                 2         0
# 3          2              164.0  ...                 1         1
# 4          2              164.0  ...                 0         1
#
# [5 rows x 34 columns]

# %%
# from sklearn.preprocessing import OrdinalEncoder

# oc = OrdinalEncoder()
# data_copy["make_code"] = oc.fit_transform(data_copy[["make"]])
# data_copy[["make", "make_code"]].head(11)

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   symboling              205 non-null    int64
#  1   normalized-losses      205 non-null    float64
#  2   make                   205 non-null    category
#  3   fuel-type              205 non-null    category
#  4   aspiration             205 non-null    category
#  5   num-of-doors           205 non-null    int64
#  6   body-style             205 non-null    category
#  7   drive-wheels           205 non-null    category
#  8   engine-location        205 non-null    category
#  9   wheel-base             205 non-null    float64
#  10  length                 205 non-null    float64
#  11  width                  205 non-null    float64
#  12  height                 205 non-null    float64
#  13  curb-weight            205 non-null    int64
# ...

# %%
Cat_Codes_DF = data_copy.copy()

# %%
from sklearn.model_selection import train_test_split

X = Cat_Codes_DF.loc[:, ['symboling', 'normalized-losses',  'num-of-doors', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'num-of-cylinders', 'engine-size', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg','fuel-type-code', 'aspiration-code', 'body-style-code',	'engine-locatione-code',	'engine-type-code', 'fuel-system-code', 'drive-wheels-code', 'make-code']]
y = Cat_Codes_DF.loc[:,'price']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
Prediction_Frame = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
Prediction_Frame
# Out:
#       Actual     Predicted
# 52    6795.0   6680.276081
# 181  15750.0  16062.396345
# 5    15250.0  13896.061306
# 18    5151.0   1240.912991
# 188   9995.0  10463.426286
# ..       ...           ...
# 198  18420.0  15635.685046
# 143   9960.0   9545.285978
# 24    6229.0   8833.084130
# 30    6479.0   3207.292154
# 135  15510.0  13286.567610
#
# [62 rows x 2 columns]

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R Squared Score: ', metrics.r2_score(y_test, y_pred))
print('Explained Variance Score: ', metrics.explained_variance_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 2761.4515413827135
# Mean Squared Error: 16448590.227534316
# Root Mean Squared Error: 4055.686159891359
# R Squared Score:  0.7262489292757532
# Explained Variance Score:  0.7333128779324034

# %%
fig = plt.figure(figsize=(11,5))
plt.scatter(y_test,y_pred)
plt.xlabel('y_test', fontsize=18)
plt.ylabel('y_pred', fontsize=16)

#Regression Line function
f = lambda x: x

# x values of line to plot
x = np.array(y_test)

# plot fit
plt.plot(x,f(x),lw=2.5, c="orange")
